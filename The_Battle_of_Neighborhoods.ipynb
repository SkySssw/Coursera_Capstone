# %% [markdown]
# <a href="https://colab.research.google.com/github/SkySssw/Coursera_Capstone/blob/main/The_Battle_of_Neighborhoods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# The Battle of Neighborhoods

# %% [markdown]
# # The Battle of Neighborhoods

# %% [markdown]
# ## Introduction to business problem

# %% [markdown]
# Nowaday, what business type we should set up in this area is one of the  important questions that we need to answer. So I want to answer this question by making this project. It will help many people who want to be a business owner decided what business type they should lauch in their own town.

# %% [markdown]
# ## The data and how it will be used to solve the problem

# %% [markdown]
#  - Venue Category
#  - Venue locations
#  - Venue
#  - Neighborhood
#  - Neighborhood locations
